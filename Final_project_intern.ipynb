# %% [markdown]
# <a href="https://colab.research.google.com/github/whythoSanskar/mlprojects/blob/main/Final_project_intern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel(r"/content/Book 4 (1).xlsx")
df
# Out:
#        Name  Customer_ID                product  product_cost  testingRange1  \
# 0      Jack         2201  electrical appliances         13999              1
# 1    Arkham         2202        home appliances         22000              1
# 2   Patrick         2203        beauty products          3000              0
# 3     Bruce         2204  electrical appliances         19999              1
# 4    Harley         2205        beauty products          5000              0
# 5   Natasha         2206  electrical appliances          8000              1
# 6      Rose         2207        beauty products         10000              1
# 7     Peter         2208        home appliances         19999              1
# 8     Gwenn         2209        beauty products          3000              0
# 9     Maria         2210  electrical appliances         19999              1
# 10   George         2211   electronical gadgets          3000              0
# ...

# %%
f = df['product']
g = df['Review']

plt.hist([f])
plt.glim = (1,10)
ax = plt.gca()
#ax.set_glim([1, 10])
x1,x2,y1,y2 = plt.axis()  
plt.axis((x1,x2,1,10))
plt.show()

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
x = np.array(df["Customer_ID"]).reshape(-1,1)
y = np.array(df["product_cost"])
reg = LinearRegression()
reg.fit(x,y)
y_p= reg.predict(x)
y_p
plt.scatter(x,y, color = "blue")
plt.plot(x, y_p, color = "red")
plt.show()

# %%
plt.scatter(df["Review"], df["product_cost"])
plt.show()

# %%
from sklearn.cluster import KMeans
kM = KMeans(n_clusters=3)
kM
# Out:
# KMeans(n_clusters=3)

# %%
y_pred = kM.fit_predict(df[["Review"]], df["product_cost"])

# %%
df['cluster'] = y_pred
df.head()
# Out:
#       Name  Customer_ID                product  product_cost  testingRange1  \
# 0     Jack         2201  electrical appliances         13999              1
# 1   Arkham         2202        home appliances         22000              1
# 2  Patrick         2203        beauty products          3000              0
# 3    Bruce         2204  electrical appliances         19999              1
# 4   Harley         2205        beauty products          5000              0
#
#    testingRange2  testingRange3  Gender  Review  cluster
# 0              1              0    Male      10        2
# 1              1              0    Male       8        0
# 2              1              1    Male       5        1
# 3              1              0    Male       4        1
# 4              1              1  Female       5        1

# %%
df1 = df[df.cluster==0]
df2 = df[df.cluster==1]
df3 = df[df.cluster==2]

plt.scatter(df1["Review"], df1['product_cost'], color = 'green')
plt.scatter(df2["Review"], df2['product_cost'], color = 'red')
plt.scatter(df3["Review"], df3['product_cost'], color = 'blue')

plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(df[["product_cost"]])
df["product_cost"] = scaler.transform(df[["product_cost"]])
df
# Out:
#        Name  Customer_ID                product  product_cost  testingRange1  \
# 0      Jack         2201  electrical appliances      0.578895              1
# 1    Arkham         2202        home appliances      1.000000              1
# 2   Patrick         2203        beauty products      0.000000              0
# 3     Bruce         2204  electrical appliances      0.894684              1
# 4    Harley         2205        beauty products      0.105263              0
# 5   Natasha         2206  electrical appliances      0.263158              1
# 6      Rose         2207        beauty products      0.368421              1
# 7     Peter         2208        home appliances      0.894684              1
# 8     Gwenn         2209        beauty products      0.000000              0
# 9     Maria         2210  electrical appliances      0.894684              1
# 10   George         2211   electronical gadgets      0.000000              0
# ...

# %%
km = KMeans(n_clusters=3)
y_predicted = km.fit_predict(df[["Review", "product_cost"]])
y_predicted
# Out:
# array([2, 0, 1, 1, 1, 1, 1, 0, 1, 0, 0, 1, 0, 1, 0, 2, 2, 2, 0],
#       dtype=int32)

# %%
df['cluster'] = y_predicted
df.drop('cluster', axis='columns')
df
# Out:
#        Name  Customer_ID                product  product_cost  testingRange1  \
# 0      Jack         2201  electrical appliances      0.578895              1
# 1    Arkham         2202        home appliances      1.000000              1
# 2   Patrick         2203        beauty products      0.000000              0
# 3     Bruce         2204  electrical appliances      0.894684              1
# 4    Harley         2205        beauty products      0.105263              0
# 5   Natasha         2206  electrical appliances      0.263158              1
# 6      Rose         2207        beauty products      0.368421              1
# 7     Peter         2208        home appliances      0.894684              1
# 8     Gwenn         2209        beauty products      0.000000              0
# 9     Maria         2210  electrical appliances      0.894684              1
# 10   George         2211   electronical gadgets      0.000000              0
# ...

# %%
cluster_c = kM.cluster_centers_
cluster_c
# Out:
# array([[7.57142857],
#        [4.25      ],
#        [9.5       ]])

# %%
df1 = df[df.cluster==0]
df2 = df[df.cluster==1]
df3 = df[df.cluster==2]


plt.scatter(df1["Review"], df1['product_cost'], color = 'green')
plt.scatter(df2["Review"], df2['product_cost'], color = 'red')
plt.scatter(df3["Review"], df3['product_cost'], color = 'blue')

plt.show()

# %%
df.drop(['cluster'], axis="columns")

input_1 = df.drop("testingRange1", axis="columns")
input_2 = df.drop("testingRange2", axis="columns")
input_3 = df.drop("testingRange3", axis="columns")


target_1 = df["testingRange1"]
target_2 = df["testingRange2"]
target_3 = df["testingRange3"]

# %%
df
# Out:
#        Name  Customer_ID                product  product_cost  testingRange1  \
# 0      Jack         2201  electrical appliances      0.578895              1
# 1    Arkham         2202        home appliances      1.000000              1
# 2   Patrick         2203        beauty products      0.000000              0
# 3     Bruce         2204  electrical appliances      0.894684              1
# 4    Harley         2205        beauty products      0.105263              0
# 5   Natasha         2206  electrical appliances      0.263158              1
# 6      Rose         2207        beauty products      0.368421              1
# 7     Peter         2208        home appliances      0.894684              1
# 8     Gwenn         2209        beauty products      0.000000              0
# 9     Maria         2210  electrical appliances      0.894684              1
# 10   George         2211   electronical gadgets      0.000000              0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le_Name = LabelEncoder()
le_product = LabelEncoder()
le_Gender = LabelEncoder()
input_1['name_n'] = le_Name.fit_transform(input_1['Name'].values)
input_1['product_n'] = le_product.fit_transform(input_1['product'].values)
input_1['gender_n'] = le_Gender.fit_transform(input_1['Gender'].values)

# %%
input_1.head()
# Out:
#       Name  Customer_ID                product  product_cost  testingRange2  \
# 0     Jack         2201  electrical appliances      0.578895              1
# 1   Arkham         2202        home appliances      1.000000              1
# 2  Patrick         2203        beauty products      0.000000              1
# 3    Bruce         2204  electrical appliances      0.894684              1
# 4   Harley         2205        beauty products      0.105263              1
#
#    testingRange3  Gender  Review  cluster  name_n  product_n  gender_n
# 0              0    Male      10        2       6          1         1
# 1              0    Male       8        0       0          3         1
# 2              1    Male       5        1      11          0         1
# 3              0    Male       4        1       1          1         1
# 4              1  Female       5        1       4          0         0

# %%
input_n1 = input_1.drop(['Name', 'product', 'Gender', 'cluster', 'product_cost', 'Customer_ID', 'Review'], axis = 'columns')
input_n1
# Out:
#     testingRange2  testingRange3  name_n  product_n  gender_n
# 0               1              0       6          1         1
# 1               1              0       0          3         1
# 2               1              1      11          0         1
# 3               1              0       1          1         1
# 4               1              1       4          0         0
# 5               0              1      10          1         0
# 6               0              1      13          0         0
# 7               1              0      12          3         1
# 8               1              1       3          0         0
# 9               1              0       7          1         0
# 10              1              1       2          2         1
# 11              0              1      14          2         1
# 12              0              1       8          1         1
# 13              1              0      16          3         1
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
test_model1 = DecisionTreeClassifier()
test_model1.fit(input_n1, target_1)
test_model1.score(input_n1, target_1)
# Out:
# 1.0

# %%
test_model1.predict([[1,0,6,1,1]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# array([1])

# %%
target_1
# Out:
# 0     1
# 1     1
# 2     0
# 3     1
# 4     0
# 5     1
# 6     1
# 7     1
# 8     0
# 9     1
# 10    0
# 11    1
# 12    1
# 13    1
# 14    1
# 15    1
# 16    0
# 17    1
# 18    1
# Name: testingRange1, dtype: int64

# %%
input_n1['gender_n'] = input_n1.gender_n
df.drop(['cluster'], axis='columns')
df
# Out:
#        Name  Customer_ID                product  product_cost  testingRange1  \
# 0      Jack         2201  electrical appliances      0.578895              1
# 1    Arkham         2202        home appliances      1.000000              1
# 2   Patrick         2203        beauty products      0.000000              0
# 3     Bruce         2204  electrical appliances      0.894684              1
# 4    Harley         2205        beauty products      0.105263              0
# 5   Natasha         2206  electrical appliances      0.263158              1
# 6      Rose         2207        beauty products      0.368421              1
# 7     Peter         2208        home appliances      0.894684              1
# 8     Gwenn         2209        beauty products      0.000000              0
# 9     Maria         2210  electrical appliances      0.894684              1
# 10   George         2211   electronical gadgets      0.000000              0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(input_n1.drop(['testingRange2'], axis='columns'),input_n1.gender_n,test_size=0.2)

# %%
len(X_test)
# Out:
# 4

# %%
from sklearn.ensemble import RandomForestClassifier
model_1 = RandomForestClassifier()
model_1.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
model_1.score(X_test,Y_test)
# Out:
# 1.0
